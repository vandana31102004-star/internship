# %% [markdown]
# # Types of Machine Learning
# Supervised Learning is a type of Machine Learning where the dataset contains input data along with correct output labels. The model learns the relationship between inputs and outputs so it can predict results for new data.
#
# 🔹 Understand in Simple Words
#
# Data has answers
#
# Model learns from correct answers
#
# Used for prediction
#
# 🔹 Example Thinking Process
#
# If you have:
#
# Email	Spam or Not
# Free money!!!	Spam
# Meeting at 5pm	Not Spam
#
# The model learns how to classify new emails.
#
# ✅ STEP 3: Define Unsupervised Learning
# 🔹 What to Write
#
# Definition:
#
# Unsupervised Learning is a type of Machine Learning where the dataset does not contain labeled answers. The model tries to find hidden patterns, structures, or clusters within the data.
#
# 🔹 Understand in Simple Words
#
# Data has NO answers
#
# Model finds patterns
#
# Used for grouping
#
# 🔹 Example Thinking Process
#
# If you have customer data with:
#
# Age
#
# Income
#
# Spending
#
# But no labels like “High Value Customer”
#
# The model groups similar customers together.
#
# ✅ STEP 4: Define Reinforcement Learning
# 🔹 What to Write
#
# Definition:
#
# Reinforcement Learning is a type of Machine Learning where an agent learns by interacting with an environment and receiving rewards or penalties based on its actions.
#
# 🔹 Understand in Simple Words
#
# Model takes action
#
# Gets reward or penalty
#
# Learns by trial and error
#
# 🔹 Example Thinking Process
#
# A game AI:
#
# Wins → gets reward
#
# Loses → gets penalty
#
# Improves strategy
#
# ✅ STEP 5: Create Comparison Table
#
# Now write this table in your notes:
#
# 📊 Machine Learning Comparison Table
# ML Type	Data Has Labels?	How It Learns	Real-World Examples
# Supervised Learning	Yes	Learns from input and correct output	Spam Detection, House Price Prediction
# Unsupervised Learning	No	Finds hidden patterns or clusters	Customer Segmentation, Market Basket Analysis
# Reinforcement Learning	No fixed labels	Learns through rewards and penalties	Game AI, Self-Driving Cars
